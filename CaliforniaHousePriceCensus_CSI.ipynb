# %% [markdown]
# <a href="https://colab.research.google.com/github/DevPrana/CalHousePredictor/blob/main/CaliforniaHousePriceCensus_CSI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv("https://raw.githubusercontent.com/DevPrana/CalHousePredictor/Housing-Details/housing.csv")
data.head()
# Out:
#    longitude  latitude  ...  median_house_value  ocean_proximity
# 0    -122.23     37.88  ...            452600.0         NEAR BAY
# 1    -122.22     37.86  ...            358500.0         NEAR BAY
# 2    -122.24     37.85  ...            352100.0         NEAR BAY
# 3    -122.25     37.85  ...            341300.0         NEAR BAY
# 4    -122.25     37.85  ...            342200.0         NEAR BAY
#
# [5 rows x 10 columns]

# %%
data.tail() #Used to see last few rows in data (Can specify parameter inside)
# Out:
#        longitude  latitude  ...  median_house_value  ocean_proximity
# 20635    -121.09     39.48  ...             78100.0           INLAND
# 20636    -121.21     39.49  ...             77100.0           INLAND
# 20637    -121.22     39.43  ...             92300.0           INLAND
# 20638    -121.32     39.43  ...             84700.0           INLAND
# 20639    -121.24     39.37  ...             89400.0           INLAND
#
# [5 rows x 10 columns]

# %%
data['total_bedrooms'].isnull().any()
# Out:
# True

# %%
data.shape #gives number of rows and columns as tuple
# Out:
# (20640, 10)

# %%
rows_num,columns_num= data.shape #assigning number of columns and rows to specific variables and printing them
print(rows_num)
print(columns_num)
# Out:
# 20640
# 10

# %%
data[2:4] #slicing for row data
# Out:
#    longitude  latitude  ...  median_house_value  ocean_proximity
# 2    -122.24     37.85  ...            352100.0         NEAR BAY
# 3    -122.25     37.85  ...            341300.0         NEAR BAY
#
# [2 rows x 10 columns]

# %%
data.describe()
# Out:
#           longitude      latitude  ...  median_income  median_house_value
# count  20640.000000  20640.000000  ...   20640.000000        20640.000000
# mean    -119.569704     35.631861  ...       3.870671       206855.816909
# std        2.003532      2.135952  ...       1.899822       115395.615874
# min     -124.350000     32.540000  ...       0.499900        14999.000000
# 25%     -121.800000     33.930000  ...       2.563400       119600.000000
# 50%     -118.490000     34.260000  ...       3.534800       179700.000000
# 75%     -118.010000     37.710000  ...       4.743250       264725.000000
# max     -114.310000     41.950000  ...      15.000100       500001.000000
#
# [8 rows x 9 columns]

# %%
data.columns # gives all columns same way for rows
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
data['housing_median_age'] #data for a single column
# Out:
# 0        41.0
# 1        21.0
# 2        52.0
# 3        52.0
# 4        52.0
#          ...
# 20635    25.0
# 20636    18.0
# 20637    17.0
# 20638    18.0
# 20639    16.0
# Name: housing_median_age, Length: 20640, dtype: float64

# %%
a=data[data.housing_median_age==27] #displays all housing median ages with 27 as value
a.head()
# Out:
#      longitude  latitude  ...  median_house_value  ocean_proximity
# 93     -122.27     37.79  ...            187500.0         NEAR BAY
# 168    -122.24     37.79  ...            125000.0         NEAR BAY
# 303    -122.18     37.77  ...             97500.0         NEAR BAY
# 358    -122.14     37.77  ...            279100.0         NEAR BAY
# 541    -122.28     37.77  ...            242800.0         NEAR BAY
#
# [5 rows x 10 columns]

# %%
a=data

# %%
kek=[int(i) for i in a.latitude]
a['integer_latitude']=kek

# %%
groups=a.groupby('integer_latitude')

# %%
a['integer_latitude'].mean()
# Out:
# 35.10760658914729

# %%
a.describe()
# Out:
#           longitude      latitude  ...  median_house_value  integer_latitude
# count  20640.000000  20640.000000  ...        20640.000000      20640.000000
# mean    -119.569704     35.631861  ...       206855.816909         35.107607
# std        2.003532      2.135952  ...       115395.615874          2.141580
# min     -124.350000     32.540000  ...        14999.000000         32.000000
# 25%     -121.800000     33.930000  ...       119600.000000         33.000000
# 50%     -118.490000     34.260000  ...       179700.000000         34.000000
# 75%     -118.010000     37.710000  ...       264725.000000         37.000000
# max     -114.310000     41.950000  ...       500001.000000         41.000000
#
# [8 rows x 10 columns]

# %%
cnt=0
for group,group_data in groups:
  print(group)
  print(group_data)
  cnt+=group_data.shape[0]
print(cnt)
# Out:
# 32
#        longitude  latitude  ...  ocean_proximity  integer_latitude
# 2675     -115.41     32.99  ...           INLAND                32
# 2676     -115.59     32.96  ...           INLAND                32
# 2677     -115.52     32.98  ...           INLAND                32
# 2678     -115.52     32.98  ...           INLAND                32
# 2679     -115.53     32.99  ...           INLAND                32
# ...          ...       ...  ...              ...               ...
# 15609    -116.91     32.73  ...        <1H OCEAN                32
# 15610    -116.87     32.72  ...        <1H OCEAN                32
# 15611    -116.89     32.67  ...        <1H OCEAN                32
# 15612    -116.76     32.74  ...        <1H OCEAN                32
# 15613    -116.79     32.61  ...        <1H OCEAN                32
#
# [1310 rows x 11 columns]
# 33
#        longitude  latitude  ...  ocean_proximity  integer_latitude
# ...

# %%
a=data
a
# Out:
#        longitude  latitude  ...  ocean_proximity  integer_latitude
# 0        -122.23     37.88  ...         NEAR BAY                37
# 1        -122.22     37.86  ...         NEAR BAY                37
# 2        -122.24     37.85  ...         NEAR BAY                37
# 3        -122.25     37.85  ...         NEAR BAY                37
# 4        -122.25     37.85  ...         NEAR BAY                37
# ...          ...       ...  ...              ...               ...
# 20635    -121.09     39.48  ...           INLAND                39
# 20636    -121.21     39.49  ...           INLAND                39
# 20637    -121.22     39.43  ...           INLAND                39
# 20638    -121.32     39.43  ...           INLAND                39
# 20639    -121.24     39.37  ...           INLAND                39
#
# [20640 rows x 11 columns]

# %%
al=a[a['total_bedrooms'].between(500,1000)]
al
# Out:
#        longitude  latitude  ...  ocean_proximity  integer_latitude
# 7        -122.25     37.84  ...         NEAR BAY                37
# 8        -122.26     37.84  ...         NEAR BAY                37
# 9        -122.25     37.84  ...         NEAR BAY                37
# 11       -122.26     37.85  ...         NEAR BAY                37
# 14       -122.26     37.85  ...         NEAR BAY                37
# ...          ...       ...  ...              ...               ...
# 20604    -121.54     39.12  ...           INLAND                39
# 20605    -121.58     39.12  ...           INLAND                39
# 20606    -121.57     39.12  ...           INLAND                39
# 20630    -121.32     39.29  ...           INLAND                39
# 20639    -121.24     39.37  ...           INLAND                39
#
# [6388 rows x 11 columns]

# %%
print('Number of blocks with total bedrooms between 500 and 1000 = ',al.shape[0])
# Out:
# Number of blocks with total bedrooms between 500 and 1000 =  6388

# %%
al.set_index('housing_median_age',inplace=True)

# %%
al
# Out:
#                     longitude  latitude  ...  ocean_proximity  integer_latitude
# housing_median_age                       ...
# 52.0                  -122.25     37.84  ...         NEAR BAY                37
# 42.0                  -122.26     37.84  ...         NEAR BAY                37
# 52.0                  -122.25     37.84  ...         NEAR BAY                37
# 52.0                  -122.26     37.85  ...         NEAR BAY                37
# 52.0                  -122.26     37.85  ...         NEAR BAY                37
# ...                       ...       ...  ...              ...               ...
# 17.0                  -121.54     39.12  ...           INLAND                39
# 26.0                  -121.58     39.12  ...           INLAND                39
# 30.0                  -121.57     39.12  ...           INLAND                39
# 11.0                  -121.32     39.29  ...           INLAND                39
# ...

# %%
al.reset_index(inplace=True)

# %%
al
# Out:
#       housing_median_age  longitude  ...  ocean_proximity  integer_latitude
# 0                   52.0    -122.25  ...         NEAR BAY                37
# 1                   42.0    -122.26  ...         NEAR BAY                37
# 2                   52.0    -122.25  ...         NEAR BAY                37
# 3                   52.0    -122.26  ...         NEAR BAY                37
# 4                   52.0    -122.26  ...         NEAR BAY                37
# ...                  ...        ...  ...              ...               ...
# 6383                17.0    -121.54  ...           INLAND                39
# 6384                26.0    -121.58  ...           INLAND                39
# 6385                30.0    -121.57  ...           INLAND                39
# 6386                11.0    -121.32  ...           INLAND                39
# 6387                16.0    -121.24  ...           INLAND                39
#
# [6388 rows x 11 columns]

# %%
core=data.corr()
core
# Out:
#                     longitude  latitude  ...  median_house_value  integer_latitude
# longitude            1.000000 -0.924664  ...           -0.045967         -0.911142
# latitude            -0.924664  1.000000  ...           -0.144160          0.988908
# housing_median_age  -0.108197  0.011173  ...            0.105623          0.007451
# total_rooms          0.044568 -0.036100  ...            0.134153         -0.032513
# total_bedrooms       0.069608 -0.066983  ...            0.049686         -0.061480
# population           0.099773 -0.108785  ...           -0.024650         -0.102333
# households           0.055310 -0.071035  ...            0.065843         -0.065709
# median_income       -0.015176 -0.079809  ...            0.688075         -0.077195
# median_house_value  -0.045967 -0.144160  ...            1.000000         -0.134373
# integer_latitude    -0.911142  0.988908  ...           -0.134373          1.000000
#
# [10 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
data.hist(bins=50,figsize=(30,25))
plt.show()

# %%
data.plot(kind='scatter',x='longitude',y='median_income',alpha=0.5,figsize=(20,15),c='median_house_value',cmap=plt.get_cmap('rainbow'),colorbar=True,sharex=False)
